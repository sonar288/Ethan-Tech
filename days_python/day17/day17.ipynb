# %%
import requests

# response = requests.get("https://jsonplaceholder.typicode.com/posts/1")

# print(response.status_code)   # HTTP status code (200 means OK)
# print(response.text)          # Raw response as text
# print(response.json())        # Convert JSON response to Python dictionary

# %%
# !pip install requests

# %%
import requests

# %%
data = requests.get("https://v2.jokeapi.dev/joke/Any?blacklistFlags=religious,political,racist,sexist&type=twopart").json()

# %%
type(data)
# Out:
# dict

# %%
print(data['setup'])
print(data['delivery'])
# Out:
# Why should you never talk to pi?
# Because it will go on forever.

# %%
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
client_id = "382747ce04d44dbaa92be5862f382378"
client_secret = "c546396d578041e0ae08d27e4eb19649"

# %%
def authenticate_spotify(client_id,client_secret ):
    auth_manager = SpotifyClientCredentials(client_id=client_id,client_secret=client_secret)
    return spotipy.Spotify(auth_manager=auth_manager)

# %%
sp = authenticate_spotify(client_id,client_secret)

# %%
sp.search(q='arijit',limit=1,type='track')
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=1&query=arijit&type=track',
#   'limit': 1,
#   'next': 'https://api.spotify.com/v1/search?offset=1&limit=1&query=arijit&type=track',
#   'offset': 0,
#   'previous': None,
#   'total': 1000,
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4YRxDV8wJFPHPTeXepOstw'},
#        'href': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw',
#        'id': '4YRxDV8wJFPHPTeXepOstw',
#        'name': 'Arijit Singh',
#        'type': 'artist',
#        'uri': 'spotify:artist:4YRxDV8wJFPHPTeXepOstw'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
# ...

# %%
sp.new_releases("country=IN", limit=1)
# Out:
# {'albums': {'href': 'https://api.spotify.com/v1/browse/new-releases?offset=0&limit=1',
#   'items': [{'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6rs1KAoQnFalSqSU4LTh8g'},
#       'href': 'https://api.spotify.com/v1/artists/6rs1KAoQnFalSqSU4LTh8g',
#       'id': '6rs1KAoQnFalSqSU4LTh8g',
#       'name': 'back number',
#       'type': 'artist',
#       'uri': 'spotify:artist:6rs1KAoQnFalSqSU4LTh8g'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
# ...

# %%
sp.current_playback()
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/me/player with Params: {'market': None, 'additional_types': None} returned 404 due to Invalid username
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\Waghr\AppData\Local\Programs\Python\Python313\Lib\site-packages\spotipy\client.py:274, in Spotify._internal_call(self, method, url, payload, params)
#     269 response = self._session.request(
#     270     method, url, headers=headers, proxies=self.proxies,
#     271     timeout=self.requests_timeout, **args
#     272 )
# --> 274 response.raise_for_status()
#     275 results = response.json()
#
# File c:\Users\Waghr\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# ...

# %%
sp.start_playback(uris=['spotify:track:2BpJNqPPK8WMiSUzQI3UJk'])
# Out:
# HTTP Error for PUT to https://api.spotify.com/v1/me/player/play with Params: {} returned 403 due to Player command failed: Premium required
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\Waghr\AppData\Local\Programs\Python\Python313\Lib\site-packages\spotipy\client.py:274, in Spotify._internal_call(self, method, url, payload, params)
#     269 response = self._session.request(
#     270     method, url, headers=headers, proxies=self.proxies,
#     271     timeout=self.requests_timeout, **args
#     272 )
# --> 274 response.raise_for_status()
#     275 results = response.json()
#
# File c:\Users\Waghr\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth

# Your Spotify app credentials
client_id = "YOUR_CLIENT_ID"
client_secret = "YOUR_CLIENT_SECRET"
redirect_uri = "http://localhost:8888/callback"

# Scopes required for playback control
scope = "user-modify-playback-state user-read-playback-state user-read-currently-playing"

# Authenticate user
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(
    client_id=client_id,
    client_secret=client_secret,
    redirect_uri=redirect_uri,
    scope=scope
))

# Start playback of a track
track_uri = 'spotify:track:2BpJNqPPK8WMiSUzQI3UJk'
sp.start_playback(uris=[track_uri])

print("Playback started 🎶")
# Out:
# Using 'localhost' as a redirect URI is being deprecated. Use a loopback IP address such as 127.0.0.1 to ensure your app remains functional.
